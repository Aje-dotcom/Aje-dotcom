# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Space X  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Web scraping Falcon 9 and Falcon Heavy Launches Records from Wikipedia

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# In this lab, you will be performing web scraping to collect Falcon 9 historical launch records from a Wikipedia page titled `List of Falcon 9 and Falcon Heavy launches`
#
# [https://en.wikipedia.org/wiki/List_of_Falcon\_9\_and_Falcon_Heavy_launches](https://en.wikipedia.org/wiki/List_of_Falcon\_9\_and_Falcon_Heavy_launches?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01)

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module\_1\_L2/images/Falcon9\_rocket_family.svg)

# %% [markdown]
# Falcon 9 first stage will land successfully

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/landing\_1.gif)

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/crash.gif)

# %% [markdown]
# More specifically, the launch records are stored in a HTML table shown below:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module\_1\_L2/images/falcon9-launches-wiki.png)

# %% [markdown]
# ## Objectives
#
# Web scrap Falcon 9 launch records with `BeautifulSoup`:
#
# *   Extract a Falcon 9 launch records HTML table from Wikipedia
# *   Parse the table and convert it into a Pandas data frame

# %% [markdown]
# First let's import required packages for this lab

# %%
# !pip3 install beautifulsoup4
# !pip3 install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from beautifulsoup4) (2.3.2.post1)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from requests) (3.4)

# %%
import sys
import requests
from bs4 import BeautifulSoup
import re
import unicodedata
import pandas as pd

# %% [markdown]
# and we will provide some helper functions for you to process web scraped HTML table

# %%
def date_time(table_cells):
    """
    This function returns the data and time from the HTML  table cell
    Input: the  element of a table data cell extracts extra row
    """
    return [data_time.strip() for data_time in list(table_cells.strings)][0:2]

def booster_version(table_cells):
    """
    This function returns the booster version from the HTML  table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=''.join([booster_version for i,booster_version in enumerate( table_cells.strings) if i%2==0][0:-1])
    return out

def landing_status(table_cells):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=[i for i in table_cells.strings][0]
    return out


def get_mass(table_cells):
    mass=unicodedata.normalize("NFKD", table_cells.text).strip()
    if mass:
        mass.find("kg")
        new_mass=mass[0:mass.find("kg")+2]
    else:
        new_mass=0
    return new_mass


def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    colunm_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(colunm_name.strip().isdigit()):
        colunm_name = colunm_name.strip()
        return colunm_name

# %% [markdown]
# To keep the lab tasks consistent, you will be asked to scrape the data from a snapshot of the  `List of Falcon 9 and Falcon Heavy launches` Wikipage updated on
# `9th June 2021`

# %%
static_url = "https://en.wikipedia.org/w/index.php?title=List_of_Falcon_9_and_Falcon_Heavy_launches&oldid=1027686922"

# %% [markdown]
# Next, request the HTML page from the above URL and get a `response` object

# %% [markdown]
# ### TASK 1: Request the Falcon9 Launch Wiki page from its URL

# %% [markdown]
# First, let's perform an HTTP GET method to request the Falcon9 Launch HTML page, as an HTTP response.

# %%
# use requests.get() method with the provided static_url
html = requests.get(static_url).text
# assign the response to a object

# %% [markdown]
# Create a `BeautifulSoup` object from the HTML `response`

# %%
# Use BeautifulSoup() to create a BeautifulSoup object from a response text content
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# Print the page title to verify if the `BeautifulSoup` object was created properly

# %%
# Use soup.title attribute
soup.title
# Out:
# <title>List of Falcon 9 and Falcon Heavy launches - Wikipedia</title>

# %% [markdown]
# ### TASK 2: Extract all column/variable names from the HTML table header

# %% [markdown]
# Next, we want to collect all relevant column names from the HTML table header

# %% [markdown]
# Let's try to find all tables on the wiki page first. If you need to refresh your memory about `BeautifulSoup`, please check the external reference link towards the end of this lab

# %%
# Use the find_all function in the BeautifulSoup object, with element type `table`
# Assign the result to a list called `html_tables`
html_tables = soup.find_all("table")

# %% [markdown]
# Starting from the third table is our target table contains the actual launch records.

# %%
# Let's print the third table and check its content
first_launch_table = html_tables[2]
rows = html_tables[2].find("tbody").find("tr")
print(first_launch_table)
rows
# Out:
# <table class="wikitable plainrowheaders collapsible" style="width: 100%;">
# <tbody><tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date andtime ()
# </th>
# <th scope="col">
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launchoutcome
# </th>
# <th scope="col">
# </th></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">1
# </th>
# <td>4 June 2010,<br/>18:45
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-0"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0003.1<sup class="reference" id="cite_ref-block_numbers_14-0"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/Dragon_Spacecraft_Qualification_Unit" title="Dragon Spacecraft Qualification Unit">Dragon Spacecraft Qualification Unit</a>
# </td>
# <td>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/SpaceX" title="SpaceX">SpaceX</a>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success
# </td>
# <td class="table-failure" style="background: #FFC7C7; vertical-align: middle; text-align: center;">Failure<sup class="reference" id="cite_ref-ns20110930_15-0"><a href="#cite_note-ns20110930-15">[9]</a></sup><sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[10]</a></sup><br/><small>(parachute)</small>
# </td></tr>
# <tr>
# <td colspan="9">First flight of Falcon 9 v1.0.<sup class="reference" id="cite_ref-sfn20100604_17-0"><a href="#cite_note-sfn20100604-17">[11]</a></sup> Used a boilerplate version of Dragon capsule which was not designed to separate from the second stage.<small>(<a href="#First_flight_of_Falcon_9">more details below</a>)</small> Attempted to recover the first stage by parachuting it into the ocean, but it burned up on reentry, before the parachutes even deployed.<sup class="reference" id="cite_ref-parachute_18-0"><a href="#cite_note-parachute-18">[12]</a></sup>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">2
# </th>
# <td>8 December 2010,<br/>15:43<sup class="reference" id="cite_ref-spaceflightnow_Clark_Launch_Report_19-0"><a href="#cite_note-spaceflightnow_Clark_Launch_Report-19">[13]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-1"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0004.1<sup class="reference" id="cite_ref-block_numbers_14-1"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_Dragon" title="SpaceX Dragon">Dragon</a> <a class="mw-redirect" href="/wiki/COTS_Demo_Flight_1" title="COTS Demo Flight 1">demo flight C1</a><br/>(Dragon C101)
# </td>
# <td>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a href="/wiki/International_Space_Station" title="International Space Station">ISS</a>)
# </td>
# <td><style data-mw-deduplicate="TemplateStyles:r1126788409">.mw-parser-output .plainlist ol,.mw-parser-output .plainlist ul{line-height:inherit;list-style:none;margin:0;padding:0}.mw-parser-output .plainlist ol li,.mw-parser-output .plainlist ul li{margin-bottom:0}</style><div class="plainlist">
# <ul><li><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Orbital_Transportation_Services" title="Commercial Orbital Transportation Services">COTS</a>)</li>
# <li><a href="/wiki/National_Reconnaissance_Office" title="National Reconnaissance Office">NRO</a></li></ul>
# </div>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-ns20110930_15-1"><a href="#cite_note-ns20110930-15">[9]</a></sup>
# </td>
# <td class="table-failure" style="background: #FFC7C7; vertical-align: middle; text-align: center;">Failure<sup class="reference" id="cite_ref-ns20110930_15-2"><a href="#cite_note-ns20110930-15">[9]</a></sup><sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[14]</a></sup><br/><small>(parachute)</small>
# </td></tr>
# <tr>
# <td colspan="9">Maiden flight of <a class="mw-redirect" href="/wiki/Dragon_capsule" title="Dragon capsule">Dragon capsule</a>, consisting of over 3 hours of testing thruster maneuvering and reentry.<sup class="reference" id="cite_ref-spaceflightnow_Clark_unleashing_Dragon_21-0"><a href="#cite_note-spaceflightnow_Clark_unleashing_Dragon-21">[15]</a></sup> Attempted to recover the first stage by parachuting it into the ocean, but it disintegrated upon reentry, before the parachutes were deployed.<sup class="reference" id="cite_ref-parachute_18-1"><a href="#cite_note-parachute-18">[12]</a></sup> <small>(<a href="#COTS_demo_missions">more details below</a>)</small> It also included two <a href="/wiki/CubeSat" title="CubeSat">CubeSats</a>,<sup class="reference" id="cite_ref-NRO_Taps_Boeing_for_Next_Batch_of_CubeSats_22-0"><a href="#cite_note-NRO_Taps_Boeing_for_Next_Batch_of_CubeSats-22">[16]</a></sup> and a wheel of <a href="/wiki/Brou%C3%A8re" title="Brouère">Brouère</a> cheese.
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">3
# </th>
# <td>22 May 2012,<br/>07:44<sup class="reference" id="cite_ref-BBC_new_era_23-0"><a href="#cite_note-BBC_new_era-23">[17]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-2"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0005.1<sup class="reference" id="cite_ref-block_numbers_14-2"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_Dragon" title="SpaceX Dragon">Dragon</a> <a class="mw-redirect" href="/wiki/Dragon_C2%2B" title="Dragon C2+">demo flight C2+</a><sup class="reference" id="cite_ref-C2_24-0"><a href="#cite_note-C2-24">[18]</a></sup><br/>(Dragon C102)
# </td>
# <td>525 kg (1,157 lb)<sup class="reference" id="cite_ref-25"><a href="#cite_note-25">[19]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a href="/wiki/International_Space_Station" title="International Space Station">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Orbital_Transportation_Services" title="Commercial Orbital Transportation Services">COTS</a>)
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-26"><a href="#cite_note-26">[20]</a></sup>
# </td>
# <td class="table-noAttempt" style="background: #EEE; vertical-align: middle; white-space: nowrap; text-align: center;">No attempt
# </td></tr>
# <tr>
# <td colspan="9">Dragon spacecraft demonstrated a series of tests before it was allowed to approach the <a href="/wiki/International_Space_Station" title="International Space Station">International Space Station</a>. Two days later, it became the first commercial spacecraft to board the ISS.<sup class="reference" id="cite_ref-BBC_new_era_23-1"><a href="#cite_note-BBC_new_era-23">[17]</a></sup> <small>(<a href="#COTS_demo_missions">more details below</a>)</small>
# </td></tr>
# <tr>
# <th rowspan="3" scope="row" style="text-align:center;">4
# </th>
# <td rowspan="2">8 October 2012,<br/>00:35<sup class="reference" id="cite_ref-SFN_LLog_27-0"><a href="#cite_note-SFN_LLog-27">[21]</a></sup>
# </td>
# <td rowspan="2"><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-3"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0006.1<sup class="reference" id="cite_ref-block_numbers_14-3"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td rowspan="2"><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_CRS-1" title="SpaceX CRS-1">SpaceX CRS-1</a><sup class="reference" id="cite_ref-sxManifest20120925_28-0"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><br/>(Dragon C103)
# </td>
# <td>4,700 kg (10,400 lb)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a href="/wiki/International_Space_Station" title="International Space Station">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success
# </td>
# <td rowspan="2" style="background:#ececec; text-align:center;"><span class="nowrap">No attempt</span>
# </td></tr>
# <tr>
# <td><a href="/wiki/Orbcomm_(satellite)" title="Orbcomm (satellite)">Orbcomm-OG2</a><sup class="reference" id="cite_ref-Orbcomm_29-0"><a href="#cite_note-Orbcomm-29">[23]</a></sup>
# </td>
# <td>172 kg (379 lb)<sup class="reference" id="cite_ref-gunter-og2_30-0"><a href="#cite_note-gunter-og2-30">[24]</a></sup>
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Orbcomm" title="Orbcomm">Orbcomm</a>
# </td>
# <td class="table-partial" style="background: #FE9; vertical-align: middle; text-align: center;">Partial failure<sup class="reference" id="cite_ref-nyt-20121030_31-0"><a href="#cite_note-nyt-20121030-31">[25]</a></sup>
# </td></tr>
# <tr>
# <td colspan="9">CRS-1 was successful, but the <a href="/wiki/Secondary_payload" title="Secondary payload">secondary payload</a> was inserted into an abnormally low orbit and subsequently lost. This was due to one of the nine <a href="/wiki/SpaceX_Merlin" title="SpaceX Merlin">Merlin engines</a> shutting down during the launch, and NASA declining a second reignition, as per <a href="/wiki/International_Space_Station" title="International Space Station">ISS</a> visiting vehicle safety rules, the primary payload owner is contractually allowed to decline a second reignition. NASA stated that this was because SpaceX could not guarantee a high enough likelihood of the second stage completing the second burn successfully which was required to avoid any risk of secondary payload's collision with the ISS.<sup class="reference" id="cite_ref-OrbcommTotalLoss_32-0"><a href="#cite_note-OrbcommTotalLoss-32">[26]</a></sup><sup class="reference" id="cite_ref-sn20121011_33-0"><a href="#cite_note-sn20121011-33">[27]</a></sup><sup class="reference" id="cite_ref-34"><a href="#cite_note-34">[28]</a></sup>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">5
# </th>
# <td>1 March 2013,<br/>15:10
# </td>
# <td><a href="/wiki/Falcon_9_v1.0" title="Falcon 9 v1.0">F9 v1.0</a><sup class="reference" id="cite_ref-MuskMay2012_13-4"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B0007.1<sup class="reference" id="cite_ref-block_numbers_14-4"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SpaceX_CRS-2" title="SpaceX CRS-2">SpaceX CRS-2</a><sup class="reference" id="cite_ref-sxManifest20120925_28-1"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><br/>(Dragon C104)
# </td>
# <td>4,877 kg (10,752 lb)
# </td>
# <td><a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a> (<a class="mw-redirect" href="/wiki/ISS" title="ISS">ISS</a>)
# </td>
# <td><a href="/wiki/NASA" title="NASA">NASA</a> (<a href="/wiki/Commercial_Resupply_Services" title="Commercial Resupply Services">CRS</a>)
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success
# </td>
# <td class="table-noAttempt" style="background: #EEE; vertical-align: middle; white-space: nowrap; text-align: center;">No attempt
# </td></tr>
# <tr>
# <td colspan="9">Last launch of the original Falcon 9 v1.0 <a href="/wiki/Launch_vehicle" title="Launch vehicle">launch vehicle</a>, first use of the unpressurized trunk section of Dragon.<sup class="reference" id="cite_ref-sxf9_20110321_35-0"><a href="#cite_note-sxf9_20110321-35">[29]</a></sup>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">6
# </th>
# <td>29 September 2013,<br/>16:00<sup class="reference" id="cite_ref-pa20130930_36-0"><a href="#cite_note-pa20130930-36">[30]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a><sup class="reference" id="cite_ref-MuskMay2012_13-5"><a href="#cite_note-MuskMay2012-13">[7]</a></sup><br/>B1003<sup class="reference" id="cite_ref-block_numbers_14-5"><a href="#cite_note-block_numbers-14">[8]</a></sup>
# </td>
# <td><a class="mw-redirect" href="/wiki/Vandenberg_Air_Force_Base" title="Vandenberg Air Force Base">VAFB</a>,<br/><a href="/wiki/Vandenberg_Space_Launch_Complex_4" title="Vandenberg Space Launch Complex 4">SLC-4E</a>
# </td>
# <td><a href="/wiki/CASSIOPE" title="CASSIOPE">CASSIOPE</a><sup class="reference" id="cite_ref-sxManifest20120925_28-2"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><sup class="reference" id="cite_ref-CASSIOPE_MDA_37-0"><a href="#cite_note-CASSIOPE_MDA-37">[31]</a></sup>
# </td>
# <td>500 kg (1,100 lb)
# </td>
# <td><a href="/wiki/Polar_orbit" title="Polar orbit">Polar orbit</a> <a href="/wiki/Low_Earth_orbit" title="Low Earth orbit">LEO</a>
# </td>
# <td><a href="/wiki/Maxar_Technologies" title="Maxar Technologies">MDA</a>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-pa20130930_36-1"><a href="#cite_note-pa20130930-36">[30]</a></sup>
# </td>
# <td class="table-no2" style="background: #FFE3E3; color: black; vertical-align: middle; text-align: center;">Uncontrolled<br/><small>(ocean)</small><sup class="reference" id="cite_ref-ocean_landing_38-0"><a href="#cite_note-ocean_landing-38">[d]</a></sup>
# </td></tr>
# <tr>
# <td colspan="9">First commercial mission with a private customer, first launch from Vandenberg, and demonstration flight of Falcon 9 v1.1 with an improved 13-tonne to LEO capacity.<sup class="reference" id="cite_ref-sxf9_20110321_35-1"><a href="#cite_note-sxf9_20110321-35">[29]</a></sup> After separation from the second stage carrying Canadian commercial and scientific satellites, the first stage booster performed a controlled reentry,<sup class="reference" id="cite_ref-39"><a href="#cite_note-39">[32]</a></sup> and an <a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">ocean touchdown test</a> for the first time. This provided good test data, even though the booster started rolling as it neared the ocean, leading to the shutdown of the central engine as the roll depleted it of fuel, resulting in a hard impact with the ocean.<sup class="reference" id="cite_ref-pa20130930_36-2"><a href="#cite_note-pa20130930-36">[30]</a></sup> This was the first known attempt of a rocket engine being lit to perform a supersonic retro propulsion, and allowed SpaceX to enter a public-private partnership with <a href="/wiki/NASA" title="NASA">NASA</a> and its Mars entry, descent, and landing technologies research projects.<sup class="reference" id="cite_ref-40"><a href="#cite_note-40">[33]</a></sup> <small>(<a href="#Maiden_flight_of_v1.1">more details below</a>)</small>
# </td></tr>
# <tr>
# <th rowspan="2" scope="row" style="text-align:center;">7
# </th>
# <td>3 December 2013,<br/>22:41<sup class="reference" id="cite_ref-sfn_wwls20130624_41-0"><a href="#cite_note-sfn_wwls20130624-41">[34]</a></sup>
# </td>
# <td><a href="/wiki/Falcon_9_v1.1" title="Falcon 9 v1.1">F9 v1.1</a><br/>B1004
# </td>
# <td><a href="/wiki/Cape_Canaveral_Space_Force_Station" title="Cape Canaveral Space Force Station">CCAFS</a>,<br/><a href="/wiki/Cape_Canaveral_Space_Launch_Complex_40" title="Cape Canaveral Space Launch Complex 40">SLC-40</a>
# </td>
# <td><a href="/wiki/SES-8" title="SES-8">SES-8</a><sup class="reference" id="cite_ref-sxManifest20120925_28-3"><a href="#cite_note-sxManifest20120925-28">[22]</a></sup><sup class="reference" id="cite_ref-spx-pr_42-0"><a href="#cite_note-spx-pr-42">[35]</a></sup><sup class="reference" id="cite_ref-aw20110323_43-0"><a href="#cite_note-aw20110323-43">[36]</a></sup>
# </td>
# <td>3,170 kg (6,990 lb)
# </td>
# <td><a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">GTO</a>
# </td>
# <td><a href="/wiki/SES_S.A." title="SES S.A.">SES</a>
# </td>
# <td class="table-success" style="background: #9EFF9E; vertical-align: middle; text-align: center;">Success<sup class="reference" id="cite_ref-SNMissionStatus7_44-0"><a href="#cite_note-SNMissionStatus7-44">[37]</a></sup>
# </td>
# <td class="table-noAttempt" style="background: #EEE; vertical-align: middle; white-space: nowrap; text-align: center;">No attempt<br/><sup class="reference" id="cite_ref-sf10120131203_45-0"><a href="#cite_note-sf10120131203-45">[38]</a></sup>
# </td></tr>
# <tr>
# <td colspan="9">First <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">Geostationary transfer orbit</a> (GTO) launch for Falcon 9,<sup class="reference" id="cite_ref-spx-pr_42-1"><a href="#cite_note-spx-pr-42">[35]</a></sup> and first successful reignition of the second stage.<sup class="reference" id="cite_ref-46"><a href="#cite_note-46">[39]</a></sup> SES-8 was inserted into a <a href="/wiki/Geostationary_transfer_orbit" title="Geostationary transfer orbit">Super-Synchronous Transfer Orbit</a> of 79,341 km (49,300 mi) in apogee with an <a href="/wiki/Orbital_inclination" title="Orbital inclination">inclination</a> of 20.55° to the <a href="/wiki/Equator" title="Equator">equator</a>.
# </td></tr></tbody></table>
# <tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date andtime ()
# </th>
# <th scope="col">
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launchoutcome
# </th>
# <th scope="col">
# </th></tr>

# %% [markdown]
# You should be able to see the columns names embedded in the table header elements `<th>` as follows:

# %% [markdown]
# ```
# <tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# ```

# %% [markdown]
# Next, we just need to iterate through the `<th>` elements and apply the provided `extract_column_from_header()` to extract column name one by one

# %%
column_names = []
# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names
for column in first_launch_table.find_all("th"):
    if extract_column_from_header(column) is not None and len(extract_column_from_header(column)) > 0:
        column_names.append(extract_column_from_header(column))

# %% [markdown]
# Check the extracted column names

# %%
print(column_names)
# Out:
# ['Flight No.', 'Date and time ( )', 'Launch site', 'Payload', 'Payload mass', 'Orbit', 'Customer', 'Launch outcome']

# %% [markdown]
# ## TASK 3: Create a data frame by parsing the launch HTML tables

# %% [markdown]
# We will create an empty dictionary with keys from the extracted column names in the previous task. Later, this dictionary will be converted into a Pandas dataframe

# %%
launch_dict= dict.fromkeys(column_names)

# Remove an irrelvant column
del launch_dict['Date and time ( )']

# Let's initial the launch_dict with each value to be an empty list
launch_dict['Flight No.'] = []
launch_dict['Launch site'] = []
launch_dict['Payload'] = []
launch_dict['Payload mass'] = []
launch_dict['Orbit'] = []
launch_dict['Customer'] = []
launch_dict['Launch outcome'] = []
# Added some new columns
launch_dict['Version Booster']=[]
launch_dict['Booster landing']=[]
launch_dict['Date']=[]
launch_dict['Time']=[]
launch_dict
# Out:
# {'Flight No.': [],
#  'Launch site': [],
#  'Payload': [],
#  'Payload mass': [],
#  'Orbit': [],
#  'Customer': [],
#  'Launch outcome': [],
#  'Version Booster': [],
#  'Booster landing': [],
#  'Date': [],
#  'Time': []}

# %% [markdown]
# Next, we just need to fill up the `launch_dict` with launch records extracted from table rows.

# %% [markdown]
# Usually, HTML tables in Wiki pages are likely to contain unexpected annotations and other types of noises, such as reference links `B0004.1[8]`, missing values `N/A [e]`, inconsistent formatting, etc.

# %% [markdown]
# To simplify the parsing process, we have provided an incomplete code snippet below to help you to fill up the `launch_dict`. Please complete the following code snippet with TODOs or you can choose to write your own logic to parse all launch tables:

# %%
extracted_row = 0
#Extract each table 
for table_number, table in enumerate(soup.find_all('table', "wikitable plainrowheaders collapsible")):
   # get table row 
    for rows in table.find_all("tr"):
        #check to see if first table heading is as number corresponding to launch a number 
        if rows.th:
            if rows.th.string:
                flight_number = rows.th.string.strip()
                flag = flight_number.isdigit()
        else:
            flag = False
        #get table element 
        row = rows.find_all('td')
        #if it is number save cells in a dictonary 
        if flag:
            extracted_row += 1
            # Flight Number value
            datatimelist = date_time(row[0])
            # TODO: Append the flight_number into launch_dict with key `Flight No.`
            launch_dict["Flight No."].append(flight_number)
            #print(flight_number)
            print('flight number is', flight_number)
            
            # Date value
            # TODO: Append the date into launch_dict with key `Date`
            date = datatimelist[0].strip(',')
            launch_dict["Date"].append(date)
            #print (date)
            print('Date is ', date)
            
            # Time value
            # TODO: Append the time into launch_dict with key `Time`
            time = datatimelist[1]
            launch_dict['Time'].append(time)
            #print(time)
            print('Time is ', time)
              
            # Booster version
            # TODO: Append the bv into launch_dict with key `Version Booster`
            bv = booster_version(row[1])
            if not(bv):
                bv = row[1].a.string
            launch_dict["Version Booster"].append(bv)
            #print(bv)
            print('Version Booster is ', bv)
            
            # Launch Site
            # TODO: Append the bv into launch_dict with key `Launch Site`
            launch_site = row[2].a.string
            launch_dict["Launch site"].append(launch_site)
            #print(launch_site)
            print('Launch site is', launch_site)
            
            # Payload
            # TODO: Append the payload into launch_dict with key `Payload`
            payload = row[3].a.string
            launch_dict["Payload"].append(payload)
            #print(payload)
            print('Payload is ', payload)
            
            # Payload Mass
            # TODO: Append the payload_mass into launch_dict with key `Payload mass`
            payload_mass = get_mass(row[4])
            launch_dict["Payload mass"].append(payload_mass)
            payload_mass = get_mass(row[4])
            #print(payload)
            print('Payload Mass is', payload_mass)
            
            # Orbit
            # TODO: Append the orbit into launch_dict with key `Orbit`
            orbit = row[5].a.string
            launch_dict["Orbit"].append(orbit)
            #print(orbit)
            print('Orbit is ', orbit)
            
            # Customer
            # TODO: Append the customer into launch_dict with key `Customer`
            #customer = row[6].a.string
            launch_dict["Customer"].append(customer)
            try:
                customer = row[6].a.string
            except AttributeError:
                    customer = ''
            #print(customer)
            print('Customer is', customer)
            
            # Launch outcome
            # TODO: Append the launch_outcome into launch_dict with key `Launch outcome`
            launch_outcome = list(row[7].strings)[0]
            launch_dict["Launch outcome"].append(launch_outcome)
            #print(launch_outcome)
            print('Launch Outcome is', launch_outcome)
            
            # Booster landing
            booster_landing = landing_status(row[8])
            # TODO: Append the launch_outcome into launch_dict with key `Booster landing`
            launch_dict['Booster landing'].append(launch_outcome)
            #print(booster_landing)
            print('Booster Landing is', booster_landing)
# Out:
# flight number is 1
# Date is  4 June 2010
# Time is  18:45
# Version Booster is  F9 v1.0B0003.1
# Launch site is CCAFS
# Payload is  Dragon Spacecraft Qualification Unit
# Payload Mass is 0
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Failure
# flight number is 2
# Date is  8 December 2010
# Time is  15:43
# Version Booster is  F9 v1.0B0004.1
# Launch site is CCAFS
# Payload is  Dragon
# Payload Mass is 0
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
# Booster Landing is Failure
# flight number is 3
# Date is  22 May 2012
# Time is  07:44
# Version Booster is  F9 v1.0B0005.1
# Launch site is CCAFS
# Payload is  Dragon
# Payload Mass is 525 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
# Booster Landing is No attempt
#
# flight number is 4
# Date is  8 October 2012
# Time is  00:35
# Version Booster is  F9 v1.0B0006.1
# Launch site is CCAFS
# Payload is  SpaceX CRS-1
# Payload Mass is 4,700 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is No attempt
# flight number is 5
# Date is  1 March 2013
# Time is  15:10
# Version Booster is  F9 v1.0B0007.1
# Launch site is CCAFS
# Payload is  SpaceX CRS-2
# Payload Mass is 4,877 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is No attempt
#
# flight number is 6
# Date is  29 September 2013
# Time is  16:00
# Version Booster is  F9 v1.1B1003
# Launch site is VAFB
# Payload is  CASSIOPE
# Payload Mass is 500 kg
# Orbit is  Polar orbit
# Customer is MDA
# Launch Outcome is Success
# Booster Landing is Uncontrolled
# flight number is 7
# Date is  3 December 2013
# Time is  22:41
# Version Booster is  F9 v1.1
# Launch site is CCAFS
# Payload is  SES-8
# Payload Mass is 3,170 kg
# Orbit is  GTO
# Customer is SES
# Launch Outcome is Success
# Booster Landing is No attempt
# flight number is 8
# Date is  6 January 2014
# Time is  22:06
# Version Booster is  F9 v1.1
# Launch site is CCAFS
# Payload is  Thaicom 6
# Payload Mass is 3,325 kg
# Orbit is  GTO
# Customer is Thaicom
# Launch Outcome is Success
# Booster Landing is No attempt
# flight number is 9
# Date is  18 April 2014
# Time is  19:25
# Version Booster is  F9 v1.1
# Launch site is Cape Canaveral
# Payload is  SpaceX CRS-3
# Payload Mass is 2,296 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Controlled
# flight number is 10
# Date is  14 July 2014
# Time is  15:15
# Version Booster is  F9 v1.1
# Launch site is Cape Canaveral
# Payload is  Orbcomm-OG2
# Payload Mass is 1,316 kg
# Orbit is  LEO
# Customer is Orbcomm
# Launch Outcome is Success
# Booster Landing is Controlled
# flight number is 11
# Date is  5 August 2014
# Time is  08:00
# Version Booster is  F9 v1.1
# Launch site is Cape Canaveral
# Payload is  AsiaSat 8
# Payload Mass is 4,535 kg
# Orbit is  GTO
# Customer is AsiaSat
# Launch Outcome is Success
# Booster Landing is No attempt
# flight number is 12
# Date is  7 September 2014
# Time is  05:00
# Version Booster is  F9 v1.1
# Launch site is Cape Canaveral
# Payload is  AsiaSat 6
# Payload Mass is 4,428 kg
# Orbit is  GTO
# Customer is AsiaSat
# Launch Outcome is Success
# Booster Landing is No attempt
#
# flight number is 13
# Date is  21 September 2014
# Time is  05:52
# Version Booster is  F9 v1.1
# Launch site is Cape Canaveral
# Payload is  SpaceX CRS-4
# Payload Mass is 2,216 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
# Booster Landing is Uncontrolled
# flight number is 14
# Date is  10 January 2015
# Time is  09:47
# Version Booster is  F9 v1.1
# Launch site is Cape Canaveral
# Payload is  SpaceX CRS-5
# Payload Mass is 2,395 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
# Booster Landing is Failure
# flight number is 15
# Date is  11 February 2015
# Time is  23:03
# Version Booster is  F9 v1.1
# Launch site is Cape Canaveral
# Payload is  DSCOVR
# Payload Mass is 570 kg
# Orbit is  HEO
# Customer is USAF
# Launch Outcome is Success
#
# Booster Landing is Controlled
# flight number is 16
# Date is  2 March 2015
# Time is  03:50
# Version Booster is  F9 v1.1
# Launch site is Cape Canaveral
# Payload is  ABS-3A
# Payload Mass is 4,159 kg
# Orbit is  GTO
# Customer is ABS
# Launch Outcome is Success
#
# Booster Landing is No attempt
# flight number is 17
# Date is  14 April 2015
# Time is  20:10
# Version Booster is  F9 v1.1
# Launch site is Cape Canaveral
# Payload is  SpaceX CRS-6
# Payload Mass is 1,898 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Failure
# flight number is 18
# Date is  27 April 2015
# Time is  23:03
# Version Booster is  F9 v1.1
# Launch site is Cape Canaveral
# Payload is  TürkmenÄlem 52°E / MonacoSAT
# Payload Mass is 4,707 kg
# Orbit is  GTO
# Customer is None
# Launch Outcome is Success
#
# Booster Landing is No attempt
# flight number is 19
# Date is  28 June 2015
# Time is  14:21
# Version Booster is  F9 v1.1
# Launch site is Cape Canaveral
# Payload is  SpaceX CRS-7
# Payload Mass is 1,952 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Failure
# Booster Landing is Precluded
# flight number is 20
# Date is  22 December 2015
# Time is  01:29
# Version Booster is  F9 FT
# Launch site is Cape Canaveral
# Payload is  Orbcomm-OG2
# Payload Mass is 2,034 kg
# Orbit is  LEO
# Customer is Orbcomm
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 21
# Date is  17 January 2016
# Time is  18:42
# Version Booster is  F9 v1.1
# Launch site is VAFB
# Payload is  Jason-3
# Payload Mass is 553 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Failure
# flight number is 22
# Date is  4 March 2016
# Time is  23:35
# Version Booster is  F9 FT
# Launch site is Cape Canaveral
# Payload is  SES-9
# Payload Mass is 5,271 kg
# Orbit is  GTO
# Customer is SES
# Launch Outcome is Success
#
# Booster Landing is Failure
# flight number is 23
# Date is  8 April 2016
# Time is  20:43
# Version Booster is  F9 FT
# Launch site is Cape Canaveral
# Payload is  SpaceX CRS-8
# Payload Mass is 3,136 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
# Booster Landing is Success
# flight number is 24
# Date is  6 May 2016
# Time is  05:21
# Version Booster is  F9 FT
# Launch site is Cape Canaveral
# Payload is  JCSAT-14
# Payload Mass is 4,696 kg
# Orbit is  GTO
# Customer is SKY Perfect JSAT Group
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 25
# Date is  27 May 2016
# Time is  21:39
# Version Booster is  F9 FT
# Launch site is Cape Canaveral
# Payload is  Thaicom 8
# Payload Mass is 3,100 kg
# Orbit is  GTO
# Customer is Thaicom
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 26
# Date is  15 June 2016
# Time is  14:29
# Version Booster is  F9 FT
# Launch site is Cape Canaveral
# Payload is  ABS-2A
# Payload Mass is 3,600 kg
# Orbit is  GTO
# Customer is ABS
# Launch Outcome is Success
#
# Booster Landing is Failure
# flight number is 27
# Date is  18 July 2016
# Time is  04:45
# Version Booster is  F9 FT
# Launch site is Cape Canaveral
# Payload is  SpaceX CRS-9
# Payload Mass is 2,257 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 28
# Date is  14 August 2016
# Time is  05:26
# Version Booster is  F9 FT
# Launch site is Cape Canaveral
# Payload is  JCSAT-16
# Payload Mass is 4,600 kg
# Orbit is  GTO
# Customer is SKY Perfect JSAT Group
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 29
# Date is  14 January 2017
# Time is  17:54
# Version Booster is  F9 FT
# Launch site is VAFB
# Payload is  Iridium NEXT
# Payload Mass is 9,600 kg
# Orbit is  Polar
# Customer is Iridium Communications
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 30
# Date is  19 February 2017
# Time is  14:39
# Version Booster is  F9 FT
# Launch site is KSC
# Payload is  SpaceX CRS-10
# Payload Mass is 2,490 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 31
# Date is  16 March 2017
# Time is  06:00
# Version Booster is  F9 FT
# Launch site is KSC
# Payload is  EchoStar 23
# Payload Mass is 5,600 kg
# Orbit is  GTO
# Customer is EchoStar
# Launch Outcome is Success
#
# Booster Landing is No attempt
# flight number is 32
# Date is  30 March 2017
# Time is  22:27
# Version Booster is  F9 FT♺
# Launch site is KSC
# Payload is  SES-10
# Payload Mass is 5,300 kg
# Orbit is  GTO
# Customer is SES
# Launch Outcome is Success
# Booster Landing is Success
# flight number is 33
# Date is  1 May 2017
# Time is  11:15
# Version Booster is  F9 FT
# Launch site is KSC
# Payload is  NROL-76
# Payload Mass is C
# Orbit is  LEO
# Customer is NRO
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 34
# Date is  15 May 2017
# Time is  23:21
# Version Booster is  F9 FT
# Launch site is KSC
# Payload is  Inmarsat-5 F4
# Payload Mass is 6,070 kg
# Orbit is  GTO
# Customer is Inmarsat
# Launch Outcome is Success
#
# Booster Landing is No attempt
# flight number is 35
# Date is  3 June 2017
# Time is  21:07
# Version Booster is  F9 FT
# Launch site is KSC
# Payload is  SpaceX CRS-11
# Payload Mass is 2,708 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 36
# Date is  23 June 2017
# Time is  19:10
# Version Booster is  F9 FTB1029.2
# Launch site is KSC
# Payload is  BulgariaSat-1
# Payload Mass is 3,669 kg
# Orbit is  GTO
# Customer is Bulsatcom
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 37
# Date is  25 June 2017
# Time is  20:25
# Version Booster is  F9 FT
# Launch site is VAFB
# Payload is  Iridium NEXT
# Payload Mass is 9,600 kg
# Orbit is  LEO
# Customer is Iridium Communications
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 38
# Date is  5 July 2017
# Time is  23:38
# Version Booster is  F9 FT
# Launch site is KSC
# Payload is  Intelsat 35e
# Payload Mass is 6,761 kg
# Orbit is  GTO
# Customer is Intelsat
# Launch Outcome is Success
#
# Booster Landing is No attempt
# flight number is 39
# Date is  14 August 2017
# Time is  16:31
# Version Booster is  F9 B4
# Launch site is KSC
# Payload is  SpaceX CRS-12
# Payload Mass is 3,310 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 40
# Date is  24 August 2017
# Time is  18:51
# Version Booster is  F9 FT
# Launch site is VAFB
# Payload is  Formosat-5
# Payload Mass is 475 kg
# Orbit is  SSO
# Customer is NSPO
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 41
# Date is  7 September 2017
# Time is  14:00
# Version Booster is  F9 B4
# Launch site is KSC
# Payload is  Boeing X-37B
# Payload Mass is 4,990 kg
# Orbit is  LEO
# Customer is USAF
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 42
# Date is  9 October 2017
# Time is  12:37
# Version Booster is  F9 B4
# Launch site is VAFB
# Payload is  Iridium NEXT
# Payload Mass is 9,600 kg
# Orbit is  Polar
# Customer is Iridium Communications
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 43
# Date is  11 October 2017
# Time is  22:53:00
# Version Booster is  F9 FTB1031.2
# Launch site is KSC
# Payload is  SES-11
# Payload Mass is 5,200 kg
# Orbit is  GTO
# Customer is SES S.A.
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 44
# Date is  30 October 2017
# Time is  19:34
# Version Booster is  F9 B4
# Launch site is KSC
# Payload is  Koreasat 5A
# Payload Mass is 3,500 kg
# Orbit is  GTO
# Customer is KT Corporation
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 45
# Date is  15 December 2017
# Time is  15:36
# Version Booster is  F9 FTB1035.2
# Launch site is Cape Canaveral
# Payload is  SpaceX CRS-13
# Payload Mass is 2,205 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 46
# Date is  23 December 2017
# Time is  01:27
# Version Booster is  F9 FTB1036.2
# Launch site is VAFB
# Payload is  Iridium NEXT
# Payload Mass is 9,600 kg
# Orbit is  Polar
# Customer is Iridium Communications
# Launch Outcome is Success
# Booster Landing is Controlled
# flight number is 47
# Date is  8 January 2018
# Time is  01:00
# Version Booster is  F9 B4
# Launch site is CCAFS
# Payload is  Zuma
# Payload Mass is C
# Orbit is  LEO
# Customer is Northrop Grumman
# Launch Outcome is Success
# Booster Landing is Success
# flight number is 48
# Date is  31 January 2018
# Time is  21:25
# Version Booster is  F9 FTB1032.2
# Launch site is CCAFS
# Payload is  GovSat-1
# Payload Mass is 4,230 kg
# Orbit is  GTO
# Customer is SES
# Launch Outcome is Success
# Booster Landing is Controlled
# flight number is 49
# Date is  22 February 2018
# Time is  14:17
# Version Booster is  F9 FTB1038.2
# Launch site is VAFB
# Payload is  Paz
# Payload Mass is 2,150 kg
# Orbit is  SSO
# Customer is Hisdesat
# Launch Outcome is Success
# Booster Landing is No attempt
# flight number is 50
# Date is  6 March 2018
# Time is  05:33
# Version Booster is  F9 B4
# Launch site is CCAFS
# Payload is  Hispasat 30W-6
# Payload Mass is 6,092 kg
# Orbit is  GTO
# Customer is Hispasat
# Launch Outcome is Success
# Booster Landing is No attempt
# flight number is 51
# Date is  30 March 2018
# Time is  14:14
# Version Booster is  F9 B4B1041.2
# Launch site is VAFB
# Payload is  Iridium NEXT
# Payload Mass is 9,600 kg
# Orbit is  Polar
# Customer is Iridium Communications
# Launch Outcome is Success
# Booster Landing is No attempt
# flight number is 52
# Date is  2 April 2018
# Time is  20:30
# Version Booster is  F9 B4B1039.2
# Launch site is CCAFS
# Payload is  SpaceX CRS-14
# Payload Mass is 2,647 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
# Booster Landing is No attempt
# flight number is 53
# Date is  18 April 2018
# Time is  22:51
# Version Booster is  F9 B4
# Launch site is CCAFS
# Payload is  Transiting Exoplanet Survey Satellite
# Payload Mass is 362 kg
# Orbit is  HEO
# Customer is NASA
# Launch Outcome is Success
# Booster Landing is Success
# flight number is 54
# Date is  11 May 2018
# Time is  20:14
# Version Booster is  F9 B5B1046.1
# Launch site is KSC
# Payload is  Bangabandhu-1
# Payload Mass is 3,600 kg
# Orbit is  GTO
# Customer is Thales-Alenia
# Launch Outcome is Success
# Booster Landing is Success
# flight number is 55
# Date is  22 May 2018
# Time is  19:47
# Version Booster is  F9 B4B1043.2
# Launch site is VAFB
# Payload is  Iridium NEXT
# Payload Mass is 6,460 kg
# Orbit is  Polar
# Customer is Iridium Communications
# Launch Outcome is Success
# Booster Landing is No attempt
# flight number is 56
# Date is  4 June 2018
# Time is  04:45
# Version Booster is  F9 B4B1040.2
# Launch site is CCAFS
# Payload is  SES-12
# Payload Mass is 5,384 kg
# Orbit is  GTO
# Customer is SES
# Launch Outcome is Success
# Booster Landing is No attempt
# flight number is 57
# Date is  29 June 2018
# Time is  09:42
# Version Booster is  F9 B4B1045.2
# Launch site is CCAFS
# Payload is  SpaceX CRS-15
# Payload Mass is 2,697 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
# Booster Landing is No attempt
# flight number is 58
# Date is  22 July 2018
# Time is  05:50
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  Telstar 19V
# Payload Mass is 7,075 kg
# Orbit is  GTO
# Customer is Telesat
# Launch Outcome is Success
# Booster Landing is Success
# flight number is 59
# Date is  25 July 2018
# Time is  11:39
# Version Booster is  F9 B5B1048
# Launch site is VAFB
# Payload is  Iridium NEXT
# Payload Mass is 9,600 kg
# Orbit is  Polar
# Customer is Iridium Communications
# Launch Outcome is Success
# Booster Landing is Success
# flight number is 60
# Date is  7 August 2018
# Time is  05:18
# Version Booster is  F9 B5B1046.2
# Launch site is CCAFS
# Payload is  Merah Putih
# Payload Mass is 5,800 kg
# Orbit is  GTO
# Customer is Telkom Indonesia
# Launch Outcome is Success
# Booster Landing is Success
# flight number is 61
# Date is  10 September 2018
# Time is  04:45
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  Telstar 18V
# Payload Mass is 7,060 kg
# Orbit is  GTO
# Customer is Telesat
# Launch Outcome is Success
# Booster Landing is Success
# flight number is 62
# Date is  8 October 2018
# Time is  02:22
# Version Booster is  F9 B5B1048.2
# Launch site is VAFB
# Payload is  SAOCOM 1A
# Payload Mass is 3,000 kg
# Orbit is  SSO
# Customer is CONAE
# Launch Outcome is Success
# Booster Landing is Success
# flight number is 63
# Date is  15 November 2018
# Time is  20:46
# Version Booster is  F9 B5B1047.2
# Launch site is KSC
# Payload is  Es'hail 2
# Payload Mass is 5,300 kg
# Orbit is  GTO
# Customer is Es'hailSat
# Launch Outcome is Success
# Booster Landing is Success
# flight number is 64
# Date is  3 December 2018
# Time is  18:34:05
# Version Booster is  F9 B5B1046.3
# Launch site is VAFB
# Payload is  SSO-A
# Payload Mass is ~4,000 kg
# Orbit is  SSO
# Customer is Spaceflight Industries
# Launch Outcome is Success
# Booster Landing is Success
# flight number is 65
# Date is  5 December 2018
# Time is  18:16
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  SpaceX CRS-16
# Payload Mass is 2,500 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Failure
# flight number is 66
# Date is  23 December 2018
# Time is  13:51
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  GPS III
# Payload Mass is 4,400 kg
# Orbit is  MEO
# Customer is USAF
# Launch Outcome is Success
# Booster Landing is No attempt
# flight number is 67
# Date is  11 January 2019
# Time is  15:31
# Version Booster is  F9 B5B1049.2
# Launch site is VAFB
# Payload is  Iridium NEXT
# Payload Mass is 9,600 kg
# Orbit is  Polar
# Customer is Iridium Communications
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 68
# Date is  22 February 2019
# Time is  01:45
# Version Booster is  F9 B5B1048.3
# Launch site is CCAFS
# Payload is  Nusantara Satu
# Payload Mass is 4,850 kg
# Orbit is  GTO
# Customer is PSN
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 69
# Date is  2 March 2019
# Time is  07:49
# Version Booster is  F9 B5[268]
# Launch site is KSC
# Payload is  Crew Dragon Demo-1
# Payload Mass is 12,055 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 70
# Date is  4 May 2019
# Time is  06:48
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  SpaceX CRS-17
# Payload Mass is 2,495 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 71
# Date is  24 May 2019
# Time is  02:30
# Version Booster is  F9 B5B1049.3
# Launch site is CCAFS
# Payload is  Starlink
# Payload Mass is 13,620 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 72
# Date is  12 June 2019
# Time is  14:17
# Version Booster is  F9 B5B1051.2
# Launch site is VAFB
# Payload is  RADARSAT Constellation
# Payload Mass is 4,200 kg
# Orbit is  SSO
# Customer is Canadian Space Agency
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 73
# Date is  25 July 2019
# Time is  22:01
# Version Booster is  F9 B5B1056.2
# Launch site is CCAFS
# Payload is  SpaceX CRS-18
# Payload Mass is 2,268 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 74
# Date is  6 August 2019
# Time is  23:23
# Version Booster is  F9 B5B1047.3
# Launch site is CCAFS
# Payload is  AMOS-17
# Payload Mass is 6,500 kg
# Orbit is  GTO
# Customer is Spacecom
# Launch Outcome is Success
#
# Booster Landing is No attempt
# flight number is 75
# Date is  11 November 2019
# Time is  14:56
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 76
# Date is  5 December 2019
# Time is  17:29
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  SpaceX CRS-19
# Payload Mass is 2,617 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 77
# Date is  17 December 2019
# Time is  00:10
# Version Booster is  F9 B5B1056.3
# Launch site is CCAFS
# Payload is  JCSat-18
# Payload Mass is 6,956 kg
# Orbit is  GTO
# Customer is Sky Perfect JSAT
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 78
# Date is  7 January 2020
# Time is  02:19:21
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 79
# Date is  19 January 2020
# Time is  15:30
# Version Booster is  F9 B5
# Launch site is KSC
# Payload is  Crew Dragon in-flight abort test
# Payload Mass is 12,050 kg
# Orbit is  Sub-orbital
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is No attempt
#
# flight number is 80
# Date is  29 January 2020
# Time is  14:07
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 81
# Date is  17 February 2020
# Time is  15:05
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Failure
# flight number is 82
# Date is  7 March 2020
# Time is  04:50
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  SpaceX CRS-20
# Payload Mass is 1,977 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 83
# Date is  18 March 2020
# Time is  12:16
# Version Booster is  F9 B5
# Launch site is KSC
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Failure
# flight number is 84
# Date is  22 April 2020
# Time is  19:30
# Version Booster is  F9 B5
# Launch site is KSC
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 85
# Date is  30 May 2020
# Time is  19:22
# Version Booster is  F9 B5
# Launch site is KSC
# Payload is  Crew Dragon Demo-2
# Payload Mass is 12,530 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 86
# Date is  4 June 2020
# Time is  01:25
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 87
# Date is  13 June 2020
# Time is  09:21
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  Starlink
# Payload Mass is 15,410 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 88
# Date is  30 June 2020
# Time is  20:10:46
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  GPS III
# Payload Mass is 4,311 kg
# Orbit is  MEO
# Customer is U.S. Space Force
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 89
# Date is  20 July 2020
# Time is  21:30
# Version Booster is  F9 B5B1058.2
# Launch site is CCAFS
# Payload is  ANASIS-II
# Payload Mass is 5,000–6,000 kg
# Orbit is  GTO
# Customer is Republic of Korea Army
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 90
# Date is  7 August 2020
# Time is  05:12
# Version Booster is  F9 B5
# Launch site is KSC
# Payload is  Starlink
# Payload Mass is 14,932 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 91
# Date is  18 August 2020
# Time is  14:31
# Version Booster is  F9 B5B1049.6
# Launch site is CCAFS
# Payload is  Starlink
# Payload Mass is ~15,440 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 92
# Date is  30 August 2020
# Time is  23:18
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  SAOCOM 1B
# Payload Mass is 3,130 kg
# Orbit is  SSO
# Customer is CONAE
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 93
# Date is  3 September 2020
# Time is  12:46:14
# Version Booster is  F9 B5B1060.2
# Launch site is KSC
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 94
# Date is  6 October 2020
# Time is  11:29:34
# Version Booster is  F9 B5B1058.3
# Launch site is KSC
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 95
# Date is  18 October 2020
# Time is  12:25:57
# Version Booster is  F9 B5B1051.6
# Launch site is KSC
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 96
# Date is  24 October 2020
# Time is  15:31:34
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 97
# Date is  5 November 2020
# Time is  23:24:23
# Version Booster is  F9 B5
# Launch site is CCAFS
# Payload is  GPS III
# Payload Mass is 4,311 kg
# Orbit is  MEO
# Customer is USSF
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 98
# Date is  16 November 2020
# Time is  00:27
# Version Booster is  F9 B5
# Launch site is KSC
# Payload is  Crew-1
# Payload Mass is ~12,500 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 99
# Date is  21 November 2020
# Time is  17:17:08
# Version Booster is  F9 B5
# Launch site is VAFB
# Payload is  Sentinel-6 Michael Freilich (Jason-CS A)
# Payload Mass is 1,192 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 100
# Date is  25 November 2020
# Time is  02:13
# Version Booster is  F9 B5 ♺
# Launch site is CCAFS
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 101
# Date is  6 December 2020
# Time is  16:17:08
# Version Booster is  F9 B5 ♺
# Launch site is KSC
# Payload is  SpaceX CRS-21
# Payload Mass is 2,972 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 102
# Date is  13 December 2020
# Time is  17:30:00
# Version Booster is  F9 B5 ♺
# Launch site is CCSFS
# Payload is  SXM-7
# Payload Mass is 7,000 kg
# Orbit is  GTO
# Customer is Sirius XM
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 103
# Date is  19 December 2020
# Time is  14:00:00
# Version Booster is  F9 B5 ♺
# Launch site is KSC
# Payload is  NROL-108
# Payload Mass is C
# Orbit is  LEO
# Customer is NRO
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 104
# Date is  8 January 2021
# Time is  02:15
# Version Booster is  F9 B5
# Launch site is CCSFS
# Payload is  Türksat 5A
# Payload Mass is 3,500 kg
# Orbit is  GTO
# Customer is Türksat
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 105
# Date is  20 January 2021
# Time is  13:02
# Version Booster is  F9 B5B1051.8
# Launch site is KSC
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 106
# Date is  24 January 2021
# Time is  15:00
# Version Booster is  F9 B5B1058.5
# Launch site is CCSFS
# Payload is  Transporter-1
# Payload Mass is ~5,000 kg
# Orbit is  SSO
# Customer is
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 107
# Date is  4 February 2021
# Time is  06:19
# Version Booster is  F9 B5 ♺
# Launch site is CCSFS
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 108
# Date is  16 February 2021
# Time is  03:59:37
# Version Booster is  F9 B5 ♺
# Launch site is CCSFS
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Failure
# flight number is 109
# Date is  4 March 2021
# Time is  08:24
# Version Booster is  F9 B5 ♺
# Launch site is KSC
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 110
# Date is  11 March 2021
# Time is  08:13:29
# Version Booster is  F9 B5 ♺
# Launch site is CCSFS
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 111
# Date is  14 March 2021
# Time is  10:01
# Version Booster is  F9 B5 ♺
# Launch site is KSC
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 112
# Date is  24 March 2021
# Time is  08:28
# Version Booster is  F9 B5B1060.6
# Launch site is CCSFS
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 113
# Date is  7 April 2021
# Time is  16:34
# Version Booster is  F9 B5 ♺
# Launch site is CCSFS
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 114
# Date is  23 April 2021
# Time is  9:49
# Version Booster is  F9 B5B1061.2
# Launch site is KSC
# Payload is  Crew-2
# Payload Mass is ~13,000 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 115
# Date is  29 April 2021
# Time is  03:44
# Version Booster is  F9 B5B1060.7
# Launch site is CCSFS
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 116
# Date is  4 May 2021
# Time is  19:01
# Version Booster is  F9 B5B1049.9
# Launch site is KSC
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 117
# Date is  9 May 2021
# Time is  06:42
# Version Booster is  F9 B5B1051.10
# Launch site is CCSFS
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 118
# Date is  15 May 2021
# Time is  22:56
# Version Booster is  F9 B5B1058.8
# Launch site is KSC
# Payload is  Starlink
# Payload Mass is ~14,000 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 119
# Date is  26 May 2021
# Time is  18:59
# Version Booster is  F9 B5B1063.2
# Launch site is CCSFS
# Payload is  Starlink
# Payload Mass is 15,600 kg
# Orbit is  LEO
# Customer is SpaceX
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 120
# Date is  3 June 2021
# Time is  17:29
# Version Booster is  F9 B5B1067.1
# Launch site is KSC
# Payload is  SpaceX CRS-22
# Payload Mass is 3,328 kg
# Orbit is  LEO
# Customer is NASA
# Launch Outcome is Success
#
# Booster Landing is Success
# flight number is 121
# Date is  6 June 2021
# Time is  04:26
# Version Booster is  F9 B5
# Launch site is CCSFS
# Payload is  SXM-8
# Payload Mass is 7,000 kg
# Orbit is  GTO
# Customer is Sirius XM
# Launch Outcome is Success
#
# Booster Landing is Success

# %% [markdown]
# After you have fill in the parsed launch record values into `launch_dict`, you can create a dataframe from it.

# %%
#df = pd.DataFrame(launch_dict)

# %%
df= pd.DataFrame({ key:pd.Series(value) for key, value in launch_dict.items() })
df.to_csv('spacex_web_scraped.csv', index=False)
df.head()
df
# Out:
#     Flight No. Launch site                               Payload Payload mass  \
# 0            1       CCAFS  Dragon Spacecraft Qualification Unit            0
# 1            1       CCAFS  Dragon Spacecraft Qualification Unit            0
# 2            1       CCAFS  Dragon Spacecraft Qualification Unit            0
# 3            1       CCAFS  Dragon Spacecraft Qualification Unit            0
# 4            1       CCAFS  Dragon Spacecraft Qualification Unit            0
# ..         ...         ...                                   ...          ...
# 567        117       CCSFS                              Starlink    15,600 kg
# 568        118         KSC                              Starlink   ~14,000 kg
# 569        119       CCSFS                              Starlink    15,600 kg
# 570        120         KSC                         SpaceX CRS-22     3,328 kg
# 571        121       CCSFS                                 SXM-8     7,000 kg
#
#     Orbit Customer Launch outcome Version Booster Booster landing  \
# 0     LEO   SpaceX      Success\n  F9 v1.0B0003.1       Success\n
# 1     LEO   SpaceX      Success\n  F9 v1.0B0003.1         Success
# 2     LEO   SpaceX      Success\n  F9 v1.0B0003.1         Success
# 3     LEO   SpaceX      Success\n  F9 v1.0B0003.1       Success\n
# 4     LEO   SpaceX      Success\n  F9 v1.0B0003.1       Success\n
# ..    ...      ...            ...             ...             ...
# 567   LEO   SpaceX      Success\n   F9 B5B1051.10             NaN
# 568   LEO     NASA      Success\n    F9 B5B1058.8             NaN
# 569   LEO      NaN            NaN    F9 B5B1063.2             NaN
# 570   LEO      NaN            NaN    F9 B5B1067.1             NaN
# 571   GTO      NaN            NaN           F9 B5             NaN
#
#             Date   Time
# 0    4 June 2010  18:45
# 1    4 June 2010  18:45
# 2    4 June 2010  18:45
# 3    4 June 2010  18:45
# 4    4 June 2010  18:45
# ..           ...    ...
# 567   9 May 2021  06:42
# 568  15 May 2021  22:56
# 569  26 May 2021  18:59
# 570  3 June 2021  17:29
# 571  6 June 2021  04:26
#
# [572 rows x 11 columns]

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section, but to make the answers consistent and in case you have difficulties finishing this lab.
#
# Following labs will be using a provided dataset to make each lab independent.

# %% [markdown]
# <code>df.to_csv('spacex_web_scraped.csv', index=False)</code>

# %%
df.to_csv('spacex_web_scraped.csv', index=False)

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">Yan Luo</a>

# %% [markdown]
# <a href="https://www.linkedin.com/in/nayefaboutayoun/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">Nayef Abou Tayoun</a>

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description          |
# | ----------------- | ------- | ---------- | --------------------------- |
# | 2021-06-09        | 1.0     | Yan Luo    | Tasks updates               |
# | 2020-11-10        | 1.0     | Nayef      | Created the initial version |

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
