# %% [markdown]
# <a href="https://colab.research.google.com/github/Aje-dotcom/Aje-dotcom/blob/master/YT_GoogleDrv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Install necessary libraries
# !pip install pytube google-auth google-auth-oauthlib google-auth-httplib2 google-api-python-client oauth2client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.9 MB/s eta 0:00:00
# ...

# %%
# !pip install yt-dlp
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 48.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# <h4><b>YouTube to Google Drive Downloader (Colab)</h4></b><br>
# This Jupyter Notebook will guide you through the process of downloading a YouTube video and saving it directly to your Google Drive.

# %%
# 2. Mount Google Drive
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import yt_dlp
import os

# @param {type:"string"} youtube_url
youtube_url = "https://youtu.be/Yb8pGWKzpkU?si=21WvwJ6JPJt7A8Xf"

# Download path in Google Drive
download_path = '/content/drive/My Drive/'

ydl_opts = {
    'format': 'best',
    'outtmpl': os.path.join(download_path, '%(title)s.%(ext)s'),
}

try:
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        print(f"Downloading video...")
        ydl.download([youtube_url])
    print("Download complete!")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# ...
# [youtube] Extracting URL: https://youtu.be/Yb8pGWKzpkU?si=21WvwJ6JPJt7A8Xf
# [youtube] Yb8pGWKzpkU: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] Yb8pGWKzpkU: Downloading android vr player API JSON
# [info] Yb8pGWKzpkU: Downloading 1 format(s): 18
# [download] Destination: /content/drive/My Drive/Deep Learning Basics.mp4
# [download] 100% of   89.25MiB in 00:00:12 at 7.06MiB/s
# Download complete!

# %%
from pytube import YouTube
import os

# @param {type:"string"} youtube_url
youtube_url = "https://youtu.be/Yb8pGWKzpkU?si=21WvwJ6JPJt7A8Xf" # Replace with your YouTube video URL

# Download path in Google Drive
download_path = '/content/drive/My Drive/'

try:
    yt = YouTube(youtube_url)
    # Select the best quality stream, you can modify this as needed
    stream = yt.streams.get_highest_resolution()
    print(f"Downloading: {yt.title}...")
    stream.download(output_path=download_path)
    print("Download complete!")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: HTTP Error 400: Bad Request

# %% [markdown]
# This notebook will download the video directly to your specified Google Drive path after you run the cells sequentially and authorize access. Remember to replace "YOUR_YOUTUBE_URL" with the actual YouTube link.
